# %% [markdown]
# # Introduction to Jupyter Notebook

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/google/colab/drive.py)

# %%
print("Hello World!")

# %%
import os

# %%
os.getcwd()
